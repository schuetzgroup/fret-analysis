# %%
# %matplotlib widget

import sys
import os

import matplotlib.pyplot as plt
plt.ioff()
    
from smfret_analysis import print_info, Inspector

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print_info()
# Out:
# smFRET analysis software version 2.1
# (git revision 2.1-4-g6be30e8)
# Output version 8
# Using sdt-python version 13.4

# %%
insp = Inspector()

# %%
insp.mark_track()

# %%
insp.show_track()

# %%
insp.raw_features()

# %%
insp.show_all_tracks()

# %%
insp.plot_tracks((("donor", "frame"), ("fret", "d_mass")),
                 (("donor", "frame"), ("fret", "a_mass")))
