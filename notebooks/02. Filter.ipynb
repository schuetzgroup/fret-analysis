# %%
import sys
import os
    
from smfret_analysis import Filter, print_info
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print_info()
# Out:
# smFRET analysis software version 1.0.dev
# Output version 7
# Using sdt-python version 13.0.dev

# %%
filt = Filter(data_dir="data")

# %%
filt.find_acc_bleach_options("sc")
# Out:
# interactive(children=(IntText(value=0, description='p'), FloatText(value=1000000.0, description='pen'), Output…

# %%
filt.filter_acc_bleach(1e6, 300)

# %%
filt.find_brightness_params("sc")
# Out:
# <script
#     src="http://localhost:42469/autoload.js?bokeh-autoload-element=07fbf9bb-919f-44a9-b902-4a83d1290eb6&bokeh-absolute-url=http://localhost:42469&resources=none"
#     id="07fbf9bb-919f-44a9-b902-4a83d1290eb6"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>

# %%
filt.query("0 <= fret_d_mass <= 4500 and "
           "500 <= fret_a_mass <= 4000 and "
           "fret_has_neighbor == 0")

# %%
filt.find_cell_thresh("sc")
# Out:
# interactive(children=(Dropdown(description='file', options=('sensor-H57/cells-01_SAv-100k_SSS-H57-20k_000_.SPE…

# %%
filt.filter_cell_region("sc", 85)
filt.filter_cell_region("cc", 85)

# %%
filt.calc_beam_shape_sm(channel="donor", weighted=False)
filt.calc_beam_shape_sm(channel="acceptor")

# %%
filt.find_beam_shape_thresh("donor")
# Out:
# interactive(children=(BoundedIntText(value=75, description='thresh'), Output()), _dom_classes=('widget-interac…

# %%
filt.filter_beam_shape_region("donor", 80)

# %%
filt.save_data()
